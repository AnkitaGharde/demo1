# %% [markdown]
# ## Numerical Numerical

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')                   # Load the 'tips' dataset

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Numerical Categorical

# %% [markdown]
# - bargraph
# - boxplot
# - violinplot
# - stripplot
# - swarmplot

# %% [markdown]
# ### bargraph

# %%
plt.bar(df['smoker'],df['total_bill'])

plt.show()

# %% [markdown]
# ## barplot

# %%
sns.barplot(data=df,x='sex',y='tip',errorbar=('ci', True))

plt.show()

# %%
sns.barplot(data=df,x='sex',y='tip',hue='time',errorbar=('ci', False))

plt.show()

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(data=df,x='sex',y='tip')
plt.yticks(range(1,11))
plt.show()

# %%
sns.boxplot(data=df,x='sex',y='tip',hue='time',palette='Oranges')
plt.yticks(range(1,11))
plt.show()

# %%
sns.boxplot(data=df,x='sex',y='tip',hue='smoker',palette='Purples')
plt.yticks(range(1,11))
plt.grid(color='r',ls='--')
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=df,x='sex',y='tip',hue='day',palette='Purples')
plt.yticks(range(1,11))
plt.grid(color='r',ls='--')
plt.show()

# %% [markdown]
# ## violinplot

# %%
sns.violinplot(data=df,x='day',y='total_bill')

plt.show()

# %%
sns.violinplot(data=df,x='day',y='total_bill',palette='Purples')
plt.show()

# %%
sns.violinplot(data=df,x='day',y='total_bill',hue='time')
plt.show()

# %%
sns.violinplot(data=df,x='day',y='total_bill',hue='sex')
plt.show()

# %% [markdown]
# ## stripplot

# %%
sns.stripplot(data=df,x='day',y='total_bill')
# plt.axhline(20,c='r')
# plt.axvline(2,c='r')

plt.show()

# %%
sns.stripplot(data=df,x='tip',y='sex')
# plt.axhline(20,c='r')
# plt.axvline(2,c='r')

plt.show()

# %%
sns.stripplot(data=df,x='day',y='total_bill')
plt.axhline(20,c='r')
plt.axvline(2,c='r')

plt.show()

# %% [markdown]
# ## swarmplot

# %% [raw]
# A swarm plot is very similar to a strip plot, yet the locations of points are adjusted automatically to avoid overlap even if the jitter value is not applied

# %%
sns.swarmplot(data=df,x='day',y='total_bill')
plt.axhline(20,c='k')

plt.show()

# %%
sns.swarmplot(data=df,x='day',y='total_bill',hue='day')
plt.axhline(20,c='k')
plt.show()

# %% [markdown]
# ## Categorical Categorical

# %% [markdown]
# - Side by side bar graph
# - Stacked Bar Graph

# %% [markdown]
# ### Side by side bar graph

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### crosstab()

# %%
import pandas as pd

# %%
pd.crosstab(df['sex'],df['day'])
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
pd.crosstab(df['sex'],df['day']).plot(kind='bar')

plt.show()

# %%
pd.crosstab(df['sex'],df['day']).plot(kind='bar')
plt.text(0,60,59)
plt.text(-0.1,12,10)

plt.text(-0.2,35,30)

plt.text(0.15,58,58)

plt.text(1,30,28)
plt.text(0.90,10,10)
plt.text(0.80,32,32)
plt.text(1.15,20,18)
plt.show()

# %%
pd.crosstab(df['sex'],df['day']).plot(kind='bar',stacked=True)

plt.show()

# %% [markdown]
# ### Stacked Bar Graph

# %%
pd.crosstab(df['sex'],df['day'])
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
pd.crosstab(df['sex'],df['day']).plot(kind='bar',stacked=True)

plt.show()

# %%
pd.crosstab(df['sex'],df['day']).plot(kind='bar',stacked=True)

plt.text(0,20,30,color='white')
plt.text(0,33,10,color='white')
plt.text(0,70,59,color='white')
plt.text(0,120,58,color='white')

plt.text(1,20,32,color='white')
plt.text(1,33,9,color='white')
plt.show()
