# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### Numerical Numerical

# %% [markdown]
# - Scatterplot
# - lmplot
# - regplot
# - pairplot
# - jointplot
# - heatmap
# - line

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')                   # Load the 'tips' dataset

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatterplot

# %% [raw]
# In Python, you can create scatterplots to visualize the relationship between two variables using various libraries such as Matplotlib and Seaborn. Here's how you can create a simple scatterplot using both libraries

# %% [markdown]
# #### example:

# %%
plt.scatter(df['total_bill'],df['tip'])

plt.xlabel('Total bill($)')
plt.ylabel('tip($)')
plt.title('Relationship between total_bill & tip')

plt.show()


# Create a scatter plot to visualize the relationship between 'total_bill' and 'tip' columns
# Scatter plots show how two numerical variables are related by plotting points on a two-dimensional plane

# %%
#add edgecolor

plt.scatter(df['total_bill'],df['tip'],edgecolor='r')


plt.xlabel('Total bill($)')
plt.ylabel('tip($)')
plt.title('Relationship between total_bill & tip')

plt.show()

# Scatter plots show how two numerical variables are related by plotting points on a two-dimensional plane
# 'edgecolor' sets the color of the marker edges to red ('r')

# %%
plt.scatter(df['total_bill'],df['tip'],edgecolor='r',color='g')

plt.xlabel('Total bill($)')
plt.ylabel('tip($)')
plt.title('Relationship between total_bill & tip')
plt.axhline(1,color='black',ls='--') 
plt.axhline(4,color='black',ls='--') 
plt.axvline(10,color='black',ls='--') 
plt.axvline(25,color="g",ls='-')
plt.show()

# %%
plt.scatter(df['total_bill'],df['tip'],edgecolor='r',color='g')
plt.xlabel('Total bill($)')
plt.ylabel('tip($)')
plt.title('Relationship between total_bill & tip')

plt.axhline(2,color='black',ls='--')  # Add horizontal dashed lines at y=2 and y=4 with black color
plt.axhline(4,color='k',ls='--')
plt.axvline(10,c='r',ls='--')# Add vertical dashed lines at x=10 and x=20 with red color
plt.axvline(20,c='r',ls='--')
plt.yticks(range(1,11))
plt.xticks(range(5,51,5))

plt.show()# Display the scatter plot with added lines

# %% [markdown]
# ### using sns

# %%
# #day
plt.figure(figsize=(6,4))

sns.scatterplot(data=df,x='total_bill',y='tip') 
plt.grid()
plt.show()

# %%
#smoker

plt.figure(figsize=(6,4))

sns.scatterplot(data=df,x='total_bill',y='tip',hue="smoker") 
plt.grid()
plt.show()

# %%
#sex

plt.figure(figsize=(6,4))

sns.scatterplot(data=df,x='total_bill',y='tip',hue="sex") 

plt.show()

# %%
# #time
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x='total_bill',y='tip',hue='time')
plt.show()

# %% [markdown]
# ### lmplot(Linear model plot)

# %% [raw]
# A Python Seaborn function for creating scatter plots with linear regression models to visualize and analyze the linear relationship between two variables.

# %%
sns.lmplot(data=df,x='total_bill',y='tip')

plt.show()

# %%
sns.lmplot(data=df,x='total_bill',y='tip',hue='smoker')

plt.show()

# %% [markdown]
# ## regplot

# %% [raw]
# regplot: In Python's Seaborn library, regplot is a function used to create scatter plots with an optional linear regression line to visually represent and analyze the relationship between two variables.

# %%
sns.regplot(data=df,y='size',x='total_bill')
plt.show()

# %%
# sns.regplot(data=df,x='total_bill',y='tip')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df,hue='day')
plt.show()

# %%
df1 = sns.load_dataset('flights')                   # Load the 'tips' dataset

df1
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
