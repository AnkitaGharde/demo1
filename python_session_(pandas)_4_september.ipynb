# %% [markdown]
# ## pandas

# %% [markdown]
# - rename()
# - replace()
# - indexing
# - duplicated()
# - drop_duplicates()
# - null value check
# - Missing Data Handling:
# - concat()
# - Merge
# - groupby()
# - crosstab
# - pivot
# - pivot table

# %%
import pandas as pd

# %%
df =pd.read_csv(r"C:\Users\Acer\Downloads\Employee.csv")

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df =pd.read_csv(r"C:\Users\Acer\Downloads\Employee.csv")
#       3 df
#
# File ~\anaconda\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ### rename

# %% [raw]
# #syntax
#
# variable_name.rename({old_index/column:new_index/column,old_index/column:new_index/column},
# inplace=True)

# %% [markdown]
# #### rename index

# %%
# example

df.rename({5:100})
# Out:
#        Id gender      city  experience   salary
# 0    1001      M      pune           1  10000.0
# 1    1002      F    mumbai           5  50000.0
# 2    1003      M      pune           4      NaN
# 3    1004      M      beed           6  60000.0
# 4    1005      F      beed           7  70000.0
# 100  1006      M  bhandara           5  50000.0
# 6    1007      F      beed           2  20000.0
# 7    1008      F      pune           8  80000.0
# 8    1009      F    nagpur           6  60000.0
# 9    1010      F      pune           3  30000.0
# 10   1011      M    nagpur           9  90000.0
# 11   1012      F    gondia           4  40000.0
# 12   1013      F  bhandara           1  10000.0
# 13   1014      M    gondia           8  80000.0
# 14   1015      M    nagpur           5  50000.0

# %% [markdown]
# #### column rename

# %%
df.rename({"city":"new_city"})
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %%
df.columns
# Out:
# Index(['Id', 'gender', 'city', 'experience', 'salary'], dtype='object')

# %%
df.columns=["col1","col2","col3","col4","col5"]

# %%
df
# Out:
#     col1 col2      col3  col4     col5
# 0   1001    M      pune     1  10000.0
# 1   1002    F    mumbai     5  50000.0
# 2   1003    M      pune     4      NaN
# 3   1004    M      beed     6  60000.0
# 4   1005    F      beed     7  70000.0
# 5   1006    M  bhandara     5  50000.0
# 6   1007    F      beed     2  20000.0
# 7   1008    F      pune     8  80000.0
# 8   1009    F    nagpur     6  60000.0
# 9   1010    F      pune     3  30000.0
# 10  1011    M    nagpur     9  90000.0
# 11  1012    F    gondia     4  40000.0
# 12  1013    F  bhandara     1  10000.0
# 13  1014    M    gondia     8  80000.0
# 14  1015    M    nagpur     5  50000.0

# %%
df1 = pd.DataFrame([[10,20,30],[22,56,78],[4,8,2],[23,67,45]])

df1
# Out:
#     0   1   2
# 0  10  20  30
# 1  22  56  78
# 2   4   8   2
# 3  23  67  45

# %%
df1.rename({0:'zero'})
# Out:
#        0   1   2
# zero  10  20  30
# 1     22  56  78
# 2      4   8   2
# 3     23  67  45

# %% [markdown]
# ### replace

# %% [raw]
# # replace only one value
#
# variable_name.replace(old_value,new_value,inplace=True)

# %%
df
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %% [raw]
# # replace multiple values
#
# variable_name.replace([old_value1,old_value2,old_value3][new_value1,new_value2,new_value3],inplace=True)

# %%
df.replace(["mumbai",5,"F"],["new",10,"sss"])
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002    sss       new          10  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005    sss      beed           7  70000.0
# 5   1006      M  bhandara          10  50000.0
# 6   1007    sss      beed           2  20000.0
# 7   1008    sss      pune           8  80000.0
# 8   1009    sss    nagpur           6  60000.0
# 9   1010    sss      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012    sss    gondia           4  40000.0
# 12  1013    sss  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur          10  50000.0

# %%
df
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %% [markdown]
# ### indexing

# %% [raw]
# iloc ---> integer based indexing   #integer based(index number)
# loc  ---> Label based indexing   #categorical

# %% [markdown]
# ### iloc

# %% [raw]
# The iloc() function is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column.

# %%
df
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %% [markdown]
# #### Selecting rows using integer indices

# %%
df.iloc[[13,2,6,8,11,10]]
# Out:
#       Id gender    city  experience   salary
# 13  1014      M  gondia           8  80000.0
# 2   1003      M    pune           4      NaN
# 6   1007      F    beed           2  20000.0
# 8   1009      F  nagpur           6  60000.0
# 11  1012      F  gondia           4  40000.0
# 10  1011      M  nagpur           9  90000.0

# %% [markdown]
# #### Selecting a range of columns and rows simultaneously

# %%
df.iloc[0: 5, 2: 4]     #iloc[index,columns]   [index=start:end-1,columns=start:end-1]

#df.iloc[:,[0,3,4]]
# Out:
#      city  experience
# 0    pune           1
# 1  mumbai           5
# 2    pune           4
# 3    beed           6
# 4    beed           7

# %%
df.iloc[:,[0,3,4]]
# Out:
#       Id  experience   salary
# 0   1001           1  10000.0
# 1   1002           5  50000.0
# 2   1003           4      NaN
# 3   1004           6  60000.0
# 4   1005           7  70000.0
# 5   1006           5  50000.0
# 6   1007           2  20000.0
# 7   1008           8  80000.0
# 8   1009           6  60000.0
# 9   1010           3  30000.0
# 10  1011           9  90000.0
# 11  1012           4  40000.0
# 12  1013           1  10000.0
# 13  1014           8  80000.0
# 14  1015           5  50000.0

# %% [markdown]
# ### loc

# %% [raw]
# The loc() function is label based data selecting method which means that we have to pass the name of the row or column which we want to select.

# %%
# df1.loc[[5,10,7],['Id','salary','gender']]

# df1.loc[(df1.salary>=60000)]

# df1.loc[(df1.salary>=60000) & (df1.gender=='F') & (df1.city=='nagpur') ]

# %% [markdown]
# #### example

# %%
df.loc[[5],['Id','salary','gender']]
# Out:
#      Id   salary gender
# 5  1006  50000.0      M

# %%
df.loc[(df.salary>=60000)]
# Out:
#       Id gender    city  experience   salary
# 3   1004      M    beed           6  60000.0
# 4   1005      F    beed           7  70000.0
# 7   1008      F    pune           8  80000.0
# 8   1009      F  nagpur           6  60000.0
# 10  1011      M  nagpur           9  90000.0
# 13  1014      M  gondia           8  80000.0

# %%
# example3


df.loc[(df.salary>=60000) & (df.gender=='F') & (df.city=='nagpur') ]
# Out:
#      Id gender    city  experience   salary
# 8  1009      F  nagpur           6  60000.0

# %%
######################################################################

# %%
df2 =pd.read_csv(r"data.csv")

# %%
df2
# Out:
#    sub1  sub2  sub3  sub4  sub5  sub6
# 0    50    54    45    65    60    78
# 1    63    74    54    54    47    50
# 2    41    58    65    54    45    46
# 3    78    69    56    65    63    64
# 4    96    45    60    78    52    52
# 5    96    45    60    78    52    52
# 6    35    55    66    77    52    50
# 7    65    66    45    58    63    63
# 8    35    55    66    77    52    50

# %% [markdown]
# ### duplicated()

# %%
df2.duplicated()    #row wise duplicate values
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# dtype: bool

# %%
df2.duplicated().sum()
# Out:
# 2

# %% [markdown]
# #### columnwise

# %%
df2.duplicated(subset=['sub5']).any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2.duplicated(subset=['sub5']).any()
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ### drop_duplicates()

# %%
df3 =pd.read_csv(r"C:\Users\Acer\Downloads\Employee.csv")

df3
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %% [markdown]
# ### null value check

# %%
# df1.isnull().any()
# df1.isnull().sum()

# %%
 df3.isnull()
# Out:
#        Id  gender   city  experience  salary
# 0   False   False  False       False   False
# 1   False   False  False       False   False
# 2   False   False  False       False    True
# 3   False   False  False       False   False
# 4   False   False  False       False   False
# 5   False   False  False       False   False
# 6   False   False  False       False   False
# 7   False   False  False       False   False
# 8   False   False  False       False   False
# 9   False   False  False       False   False
# 10  False   False  False       False   False
# 11  False   False  False       False   False
# 12  False   False  False       False   False
# 13  False   False  False       False   False
# 14  False   False  False       False   False

# %%
 df3.isnull().any()
# Out:
# Id            False
# gender        False
# city          False
# experience    False
# salary         True
# dtype: bool

# %%
 df3.isnull().sum()
# Out:
# Id            0
# gender        0
# city          0
# experience    0
# salary        1
# dtype: int64

# %% [markdown]
# ### Missing Data Handling:

# %% [raw]
# Deal with missing values in the DataFrame.

# %% [raw]
# df.dropna()       # Remove rows with missing values
#
# df.fillna(0)      # Replace missing values with 0
#
# df['your_column_name'].fillna(0, inplace=True)  # particular column
#
# df[['column1', 'column2', 'column3']].fillna(0, inplace=True)

# %%
df2
# Out:
#    sub1  sub2  sub3  sub4  sub5  sub6
# 0    50    54    45    65    60    78
# 1    63    74    54    54    47    50
# 2    41    58    65    54    45    46
# 3    78    69    56    65    63    64
# 4    96    45    60    78    52    52
# 5    96    45    60    78    52    52
# 6    35    55    66    77    52    50
# 7    65    66    45    58    63    63
# 8    35    55    66    77    52    50

# %%
df3
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %% [markdown]
# ### fillna()

# %%
df3.fillna(0)
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      0.0
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %%
df3.dropna()
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %% [markdown]
# ### Unique Values and Value Counts:

# %% [raw]
# unique_names = df['Name'].unique()
#
# name_counts = df['Name'].value_counts()

# %%
df2
# Out:
#    sub1  sub2  sub3  sub4  sub5  sub6
# 0    50    54    45    65    60    78
# 1    63    74    54    54    47    50
# 2    41    58    65    54    45    46
# 3    78    69    56    65    63    64
# 4    96    45    60    78    52    52
# 5    96    45    60    78    52    52
# 6    35    55    66    77    52    50
# 7    65    66    45    58    63    63
# 8    35    55    66    77    52    50

# %% [markdown]
# ### unique()

# %%
unique_names = df2['sub3'].unique()

# %%
unique_names
# Out:
# array([45, 54, 65, 56, 60, 66], dtype=int64)

# %%
df3
# Out:
#       Id gender      city  experience   salary
# 0   1001      M      pune           1  10000.0
# 1   1002      F    mumbai           5  50000.0
# 2   1003      M      pune           4      NaN
# 3   1004      M      beed           6  60000.0
# 4   1005      F      beed           7  70000.0
# 5   1006      M  bhandara           5  50000.0
# 6   1007      F      beed           2  20000.0
# 7   1008      F      pune           8  80000.0
# 8   1009      F    nagpur           6  60000.0
# 9   1010      F      pune           3  30000.0
# 10  1011      M    nagpur           9  90000.0
# 11  1012      F    gondia           4  40000.0
# 12  1013      F  bhandara           1  10000.0
# 13  1014      M    gondia           8  80000.0
# 14  1015      M    nagpur           5  50000.0

# %% [markdown]
# ### value_counts()

# %%
name_counts = df3['gender'].value_counts()              # columns=variable


name_counts
# Out:
# F    8
# M    7
# Name: gender, dtype: int64

# %%
name_counts1 = df3['experience'].value_counts()


name_counts1
# Out:
# 5    3
# 1    2
# 4    2
# 6    2
# 8    2
# 7    1
# 2    1
# 3    1
# 9    1
# Name: experience, dtype: int64

# %% [markdown]
# ### concat()

# %%
d1=pd.DataFrame({'Letter':['A','B','C'],'Number':[1,2,3]})

d1
# Out:
#   Letter  Number
# 0      A       1
# 1      B       2
# 2      C       3

# %%
d2=pd.DataFrame({'Letter':['D','E','F'],'Number':[4,5,6]})

d2
# Out:
#   Letter  Number
# 0      D       4
# 1      E       5
# 2      F       6

# %%
s=pd.concat((d2,d1))

s
# Out:
#   Letter  Number
# 0      D       4
# 1      E       5
# 2      F       6
# 0      A       1
# 1      B       2
# 2      C       3

# %%
s1=pd.concat((d2,d1),axis=1)

s1
# Out:
#   Letter  Number Letter  Number
# 0      D       4      A       1
# 1      E       5      B       2
# 2      F       6      C       3
