# %% [markdown]
# ## Numerical Numerical

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')                   # Load the 'tips' dataset

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### lmplot(Linear model plot)

# %% [raw]
# A Python Seaborn function for creating scatter plots with linear regression models to visualize and analyze the linear relationship between two variables.

# %%
sns.lmplot(data=df,x='total_bill',y='tip')

plt.show()
# Out:
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df,x='total_bill',y='tip',hue='smoker')

plt.show()
# Out:
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## regplot

# %% [raw]
# regplot: In Python's Seaborn library, regplot is a function used to create scatter plots with an optional linear regression line to visually represent and analyze the relationship between two variables.

# %%
# example1

sns.regplot(data=df,y='size',x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %% [markdown]
# ### in regplot hue not support

# %%
# example2

sns.regplot(data=df,y='size',x='total_bill',hue='smoker')   # in regplot hue not support
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # example2
# ----> 3 sns.regplot(data=df,y='size',x='total_bill',hue='smoker')   # in regplot hue not support
#       4 plt.show()
#
# TypeError: regplot() got an unexpected keyword argument 'hue'

# %%
# sns.regplot(data=df,x='total_bill',y='tip')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
sns.pairplot(df,hue='day')
plt.show()
# Out:
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(df,hue='smoker')
plt.show()
# Out:
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(df,hue='sex')
plt.show()
# Out:
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## jointplot

# %% [raw]
# A jointplot is a graphical representation in Python, typically created using the Seaborn library, that combines two different types of plots to visualize the relationship between two variables.

# %% [raw]
# scatter+hist --->Bivariate
#
# scatter+kde --->Multivariate

# %%
# example1

# plt.figure(figsize=(4,3))
sns.jointplot(data=df,x='size',y='tip')
plt.show()

# %%
# example2

sns.jointplot(data=df,x='size',y='tip',hue='time')

plt.show()

# %% [markdown]
# ## heatmap

# %% [raw]
# A heatmap is a graphical representation in Python that uses colors to display data values in a matrix or a grid. It's often used to visualize the relationships between two variables in a dataset or to show patterns in data

# %%
df1=sns.load_dataset('titanic')

df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(df1.isnull())
plt.show()

# %%
sns.heatmap(df1.corr(),annot=True,cmap='hot_r',cbar=True)

plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14268\730127006.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True,cmap='hot_r',cbar=True)

# %% [markdown]
# ## corr()

# %% [raw]
# range=-1 to 1
#
#
#
# 1=strong +ve correlated
#
# 0.5= moderate +ve correlation
#
# near to zero= low correlation
#
# -1=strong -ve correlation
#
# -0.5= moderate -ve correlation

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14268\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
cmap='hot_r'

# %%
sns.heatmap(df[['total_bill','tip']].corr(),annot=True,cmap='hot_r',cbar=True)

plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cmap='hot_r',cbar=True)

plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14268\178826958.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='hot_r',cbar=True)

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10948\3876718275.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ## line

# %% [raw]
# In Python, you can create a line plot to visualize the relationship between two variables or to display trends over a series of data points.

# %%
# Sample data
x_values = [5,6,7,8,9]
y_values = [10, 20, 15, 25, 30]

plt.plot(x_values, y_values, marker='*', linestyle='-')
# plt.xticks(range(1,11,2))
# plt.yticks(range(1,31,3))
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample Line Plot')
plt.show()

# %%
import pandas as pd

data = pd.DataFrame({'X': [1, 2, 3, 4, 5], 'Y': [10, 7, 12, 8, 15]})


sns.lineplot(x='X', y='Y', data=data, marker='*',mec='b',color='r')

plt.show()

# %% [markdown]
# ####

# %% [markdown]
# ### ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
###########################################################################################

# %% [markdown]
# # Numerical Categorical

# %% [markdown]
# - bargraph
# - boxplot
# - violinplot
# - stripplot
# - swarmplot

# %% [markdown]
# ### bargraph

# %%
plt.bar(df['smoker'],df['total_bill'])

plt.show()

# %% [markdown]
# ## barplot

# %%
sns.barplot(data=df,x='sex',y='tip',errorbar=('ci', True))

plt.show()
# Out:
# C:\Users\Fireblaze2023\anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.barplot(data=df,x='sex',y='tip',hue='time')

plt.show()

# %%
sns.barplot(data=df,x='sex',y='tip',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(data=df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(data=df,x='sex',y='tip')
plt.yticks(range(1,11))
plt.show()

# %%
sns.boxplot(data=df,x='sex',y='tip',hue='smoker',palette='Greens')
plt.yticks(range(1,11))
plt.grid(color='r',ls='--')
plt.show()

# %%
sns.boxplot(data=df,x='sex',y='tip',hue='day')
plt.yticks(range(1,11))
plt.grid(color='r',ls='--')
plt.show()

# %% [markdown]
# ## violinplot

# %%
sns.violinplot(data=df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=df,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=df,x='sex',y='tip',hue='day')
plt.show()

# %% [markdown]
# ## stripplot

# %%
sns.stripplot(data=df,x='day',y='total_bill')
plt.show()

# %% [markdown]
# ## swarmplot

# %% [raw]
# A swarm plot is very similar to a strip plot, yet the locations of points are adjusted automatically to avoid overlap even if the jitter value is not applied

# %%
sns.swarmplot(data=df,x='day',y='total_bill')
plt.axhline(20,c='k')

# %%
sns.swarmplot(data=df,x='day',y='total_bill',hue='sex')
plt.axhline(20,c='k')

# %%
sns.swarmplot(data=df,x='day',y='total_bill',hue='time')
# plt.axhline(20,c='k')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=df,x='day',y='total_bill',hue='smoker')
plt.axhline(20,c='k')

# %% [markdown]
# ## Categorical Categorical

# %% [markdown]
# - Side by side bar graph
# - Stacked Bar Graph

# %% [markdown]
# ### Side by side bar graph

# %% [markdown]
# #### crosstab()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
pd.crosstab(df['sex'],df['day'])
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
import pandas as pd

# %%
c=pd.crosstab(df['sex'],df['day']).plot(kind='bar')
# plt.text(0,60,59)
# plt.text(-0.1,12,10)
# plt.text(-0.2,35,30)
# plt.text(0.15,58,58)

# plt.text(1,30,59)

for bars in c.containers:
        c.bar_label(bars)
plt.show()

# %% [markdown]
# ### countplot()

# %%
# sns.countplot(data=df,x='sex',hue='day')

# %% [markdown]
# ### Stacked Bar Graph

# %%
pd.crosstab(df['sex'],df['day'])
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
x=pd.crosstab(df['sex'],df['day']).plot(kind='bar',stacked=True)
# plt.text(0,18,30,color='white')
# plt.text(0,33,10,color='white')
# plt.text(0,70,59,color='white')
# plt.text(0,120,58,color='white')

for bars in x.containers:
    x.bar_label(bars)
